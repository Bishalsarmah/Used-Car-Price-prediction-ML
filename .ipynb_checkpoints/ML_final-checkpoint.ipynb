# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import warnings
warnings.filterwarnings("ignore")
# Out:
# C:\Users\99bis\OneDrive\python\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\99bis\OneDrive\python\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
cars_data = pd.read_csv(r"C:\Users\99bis\Used Car Price prediction ML\Dataset\Cardetails.csv")

# %%
cars_data.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#    seats
# 0    5.0
# 1    5.0
# 2    5.0
# 3    5.0
# 4    5.0

# %%
cars_data.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'seats'],
#       dtype='object')

# %%
cars_data = cars_data.rename(columns = {'mileage(km/ltr/kg)' : 'mileage'})

# %%
cars_data.shape
# Out:
# (8128, 12)

# %%
cars_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 762.1+ KB

# %%
cars_data.isna().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# seats            221
# dtype: int64

# %% [markdown]
# We can handle null values by 2 methods-
# first one is replace the NaN value by mean of the column and
# second is remove the rows which have NaN value

# %%
nan_rows_mil = cars_data[cars_data['mileage'].isna()]

print(nan_rows_mil)
# Out:
#                                       name  year  selling_price  km_driven  \
# 13                    Maruti Swift 1.3 VXi  2007         200000      80000
# 31                      Fiat Palio 1.2 ELX  2003          70000      50000
# 78                         Tata Indica DLS  2003          50000      70000
# 87             Maruti Swift VDI BSIV W ABS  2015         475000      78000
# 119                  Maruti Swift VDI BSIV  2010         300000     120000
# ...                                    ...   ...            ...        ...
# 7846                Toyota Qualis Fleet A3  2000         200000     100000
# 7996             Hyundai Santro LS zipPlus  2000         140000      50000
# 8009  Hyundai Santro Xing XS eRLX Euro III  2006         145000      80000
# 8068             Ford Figo Aspire Facelift  2017         580000     165000
# 8103                  Maruti Swift 1.3 VXi  2006         130000     100000
#
#         fuel seller_type transmission         owner mileage engine max_power  \
# 13    Petrol  Individual       Manual  Second Owner     NaN    NaN       NaN
# 31    Petrol  Individual       Manual  Second Owner     NaN    NaN       NaN
# 78    Diesel  Individual       Manual   First Owner     NaN    NaN       NaN
# 87    Diesel      Dealer       Manual   First Owner     NaN    NaN       NaN
# 119   Diesel  Individual       Manual  Second Owner     NaN    NaN       NaN
# ...      ...         ...          ...           ...     ...    ...       ...
# 7846  Diesel  Individual       Manual   First Owner     NaN    NaN       NaN
# 7996  Petrol  Individual       Manual  Second Owner     NaN    NaN       NaN
# 8009  Petrol  Individual       Manual  Second Owner     NaN    NaN       NaN
# 8068  Diesel  Individual       Manual   First Owner     NaN    NaN       NaN
# 8103  Petrol  Individual       Manual  Second Owner     NaN    NaN       NaN
#
#       seats
# 13      NaN
# 31      NaN
# 78      NaN
# 87      NaN
# 119     NaN
# ...     ...
# 7846    NaN
# 7996    NaN
# 8009    NaN
# 8068    NaN
# 8103    NaN
#
# [221 rows x 12 columns]

# %% [markdown]
# Here we can see that when i checked NaN columns for 'Mileage' in that respective row other other column values such that 'engine','max_power','seats' are also NaN.

# %%
#percentage of missing values
cars_data.isna().mean().round(4) * 100
# Out:
# name             0.00
# year             0.00
# selling_price    0.00
# km_driven        0.00
# fuel             0.00
# seller_type      0.00
# transmission     0.00
# owner            0.00
# mileage          2.72
# engine           2.72
# max_power        2.65
# seats            2.72
# dtype: float64

# %% [markdown]
# In my opinion this rows are not providing much information about the dataset and 221 rows corresponds to less than 5% to the total data of my whole data so it's better to remove them.

# %%
cars_data.dropna(inplace = True)  #it will remove the rows which have NaN values

# %%
cars_data.shape   #shape of the data after removing NaN values
# Out:
# (7907, 12)

# %%
cars_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7907 entries, 0 to 8127
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           7907 non-null   object
#  1   year           7907 non-null   int64
#  2   selling_price  7907 non-null   int64
#  3   km_driven      7907 non-null   int64
#  4   fuel           7907 non-null   object
#  5   seller_type    7907 non-null   object
#  6   transmission   7907 non-null   object
#  7   owner          7907 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7907 non-null   object
#  11  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 803.1+ KB

# %% [markdown]
# As we can see no NaN values are here
#
# Now we'll check is there any duplicate record present in our dataset or not

# %%
cars_data.duplicated().sum()
# Out:
# 1189

# %%
duplicates = cars_data[cars_data.duplicated()]

# %%
duplicates
# Out:
#                                           name  year  selling_price  \
# 291                   Hyundai Grand i10 Sportz  2017         450000
# 296                           Maruti Swift VXI  2012         330000
# 370   Jaguar XE 2016-2019 2.0L Diesel Prestige  2017        2625000
# 371                              Lexus ES 300h  2019        5150000
# 372             Jaguar XF 2.0 Diesel Portfolio  2017        3200000
# ...                                        ...   ...            ...
# 7987             Renault Captur 1.5 Diesel RXT  2018        1265000
# 7988                  Maruti Ciaz Alpha Diesel  2019        1025000
# 8117                    Maruti Swift Dzire VDI  2015         625000
# 8126                           Tata Indigo CR4  2013         290000
# 8127                           Tata Indigo CR4  2013         290000
#
#       km_driven    fuel seller_type transmission         owner     mileage  \
# 291       35000  Petrol  Individual       Manual   First Owner   18.9 kmpl
# 296       50000  Petrol  Individual       Manual  Second Owner   18.6 kmpl
# 370        9000  Diesel      Dealer    Automatic   First Owner   13.6 kmpl
# 371       20000  Petrol      Dealer    Automatic   First Owner  22.37 kmpl
# 372       45000  Diesel      Dealer    Automatic   First Owner  19.33 kmpl
# ...         ...     ...         ...          ...           ...         ...
# 7987      12000  Diesel  Individual       Manual   First Owner  20.37 kmpl
# 7988      32000  Diesel  Individual       Manual   First Owner  28.09 kmpl
# 8117      50000  Diesel  Individual       Manual   First Owner  26.59 kmpl
# 8126      25000  Diesel  Individual       Manual   First Owner  23.57 kmpl
# 8127      25000  Diesel  Individual       Manual   First Owner  23.57 kmpl
#
#        engine   max_power  seats
# 291   1197 CC      82 bhp    5.0
# 296   1197 CC    85.8 bhp    5.0
# 370   1999 CC     177 bhp    5.0
# 371   2487 CC  214.56 bhp    5.0
# 372   1999 CC     177 bhp    5.0
# ...       ...         ...    ...
# 7987  1461 CC  108.45 bhp    5.0
# 7988  1248 CC   88.50 bhp    5.0
# 8117  1248 CC      74 bhp    5.0
# 8126  1396 CC      70 bhp    5.0
# 8127  1396 CC      70 bhp    5.0
#
# [1189 rows x 12 columns]

# %% [markdown]
# This are the identical rows present in my dataset

# %% [markdown]
# we have the drop the duplicates for better performamce of the model

# %%
cars_data.drop_duplicates(inplace=True)

# %%
cars_data.shape
# Out:
# (6718, 12)

# %%
cars_data.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'seats'],
#       dtype='object')

# %%
for col in cars_data.columns:
    print("Unique values of" + col)
    print(cars_data[col].unique)
    print('------------\n')
# Out:
# Unique values ofname
# <bound method Series.unique of 0                  Maruti Swift Dzire VDI
# 1            Skoda Rapid 1.5 TDI Ambition
# 2                Honda City 2017-2020 EXi
# 3               Hyundai i20 Sportz Diesel
# 4                  Maruti Swift VXI BSIII
#                       ...
# 8121    Maruti Wagon R VXI BS IV with ABS
# 8122           Hyundai i20 Magna 1.4 CRDi
# 8123                    Hyundai i20 Magna
# 8124                Hyundai Verna CRDi SX
# 8125               Maruti Swift Dzire ZDi
# Name: name, Length: 6718, dtype: object>
# ------------
#
# Unique values ofyear
# <bound method Series.unique of 0       2014
# 1       2014
# 2       2006
# 3       2010
# 4       2007
#         ...
# 8121    2013
# 8122    2014
# 8123    2013
# 8124    2007
# 8125    2009
# Name: year, Length: 6718, dtype: int64>
# ------------
#
# Unique values ofselling_price
# <bound method Series.unique of 0       450000
# 1       370000
# 2       158000
# 3       225000
# 4       130000
#          ...
# 8121    260000
# 8122    475000
# 8123    320000
# 8124    135000
# 8125    382000
# Name: selling_price, Length: 6718, dtype: int64>
# ------------
#
# Unique values ofkm_driven
# <bound method Series.unique of 0       145500
# 1       120000
# 2       140000
# 3       127000
# 4       120000
#          ...
# 8121     50000
# 8122     80000
# 8123    110000
# 8124    119000
# 8125    120000
# Name: km_driven, Length: 6718, dtype: int64>
# ------------
#
# Unique values offuel
# <bound method Series.unique of 0       Diesel
# 1       Diesel
# 2       Petrol
# 3       Diesel
# 4       Petrol
#          ...
# 8121    Petrol
# 8122    Diesel
# 8123    Petrol
# 8124    Diesel
# 8125    Diesel
# Name: fuel, Length: 6718, dtype: object>
# ------------
#
# Unique values ofseller_type
# <bound method Series.unique of 0       Individual
# 1       Individual
# 2       Individual
# 3       Individual
# 4       Individual
#            ...
# 8121    Individual
# 8122    Individual
# 8123    Individual
# 8124    Individual
# 8125    Individual
# Name: seller_type, Length: 6718, dtype: object>
# ------------
#
# Unique values oftransmission
# <bound method Series.unique of 0       Manual
# 1       Manual
# 2       Manual
# 3       Manual
# 4       Manual
#          ...
# 8121    Manual
# 8122    Manual
# 8123    Manual
# 8124    Manual
# 8125    Manual
# Name: transmission, Length: 6718, dtype: object>
# ------------
#
# Unique values ofowner
# <bound method Series.unique of 0                First Owner
# 1               Second Owner
# 2                Third Owner
# 3                First Owner
# 4                First Owner
#                 ...
# 8121            Second Owner
# 8122            Second Owner
# 8123             First Owner
# 8124    Fourth & Above Owner
# 8125             First Owner
# Name: owner, Length: 6718, dtype: object>
# ------------
#
# Unique values ofmileage
# <bound method Series.unique of 0        23.4 kmpl
# 1       21.14 kmpl
# 2        17.7 kmpl
# 3        23.0 kmpl
# 4        16.1 kmpl
#            ...
# 8121     18.9 kmpl
# 8122    22.54 kmpl
# 8123     18.5 kmpl
# 8124     16.8 kmpl
# 8125     19.3 kmpl
# Name: mileage, Length: 6718, dtype: object>
# ------------
#
# Unique values ofengine
# <bound method Series.unique of 0       1248 CC
# 1       1498 CC
# 2       1497 CC
# 3       1396 CC
# 4       1298 CC
#          ...
# 8121     998 CC
# 8122    1396 CC
# 8123    1197 CC
# 8124    1493 CC
# 8125    1248 CC
# Name: engine, Length: 6718, dtype: object>
# ------------
#
# Unique values ofmax_power
# <bound method Series.unique of 0           74 bhp
# 1       103.52 bhp
# 2           78 bhp
# 3           90 bhp
# 4         88.2 bhp
#            ...
# 8121      67.1 bhp
# 8122     88.73 bhp
# 8123     82.85 bhp
# 8124       110 bhp
# 8125      73.9 bhp
# Name: max_power, Length: 6718, dtype: object>
# ------------
#
# Unique values ofseats
# <bound method Series.unique of 0       5.0
# 1       5.0
# 2       5.0
# 3       5.0
# 4       5.0
#        ...
# 8121    5.0
# 8122    5.0
# 8123    5.0
# 8124    5.0
# 8125    5.0
# Name: seats, Length: 6718, dtype: float64>
# ------------

# %%
cars_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6718 entries, 0 to 8125
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           6718 non-null   object
#  1   year           6718 non-null   int64
#  2   selling_price  6718 non-null   int64
#  3   km_driven      6718 non-null   int64
#  4   fuel           6718 non-null   object
#  5   seller_type    6718 non-null   object
#  6   transmission   6718 non-null   object
#  7   owner          6718 non-null   object
#  8   mileage        6718 non-null   object
#  9   engine         6718 non-null   object
#  10  max_power      6718 non-null   object
#  11  seats          6718 non-null   float64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 682.3+ KB

# %% [markdown]
# ## Isuues i can see in my datsset
# - name is very large, so we'll just keep the brand name of the car and impoertant numerical value of torque rather than whole data
# - Fuel column is in object but should be in integer
# - milegae column has both alphabetical and numerical column but should be in numerical only
# - we have to change the categorical values into numerical values by encoding for engine,max power column also

# %%
#Creating a function for getting only the first word

# %%
def get_brand_name(car_name):
    car_name = car_name.split()[0]
    return car_name.strip(' ')

# %%
get_brand_name('Maruti Swift Dzire VDI')
# Out:
# 'Maruti'

# %%
#updating the name column with just the Brand of the car
cars_data['name'] = cars_data['name'].apply(get_brand_name)

# %%
cars_data['name'].unique()
# Out:
# array(['Maruti', 'Skoda', 'Honda', 'Hyundai', 'Toyota', 'Ford', 'Renault',
#        'Mahindra', 'Tata', 'Chevrolet', 'Datsun', 'Jeep', 'Mercedes-Benz',
#        'Mitsubishi', 'Audi', 'Volkswagen', 'BMW', 'Nissan', 'Lexus',
#        'Jaguar', 'Land', 'MG', 'Volvo', 'Daewoo', 'Kia', 'Fiat', 'Force',
#        'Ambassador', 'Ashok', 'Isuzu', 'Opel'], dtype=object)

# %%
cars_data
# Out:
#          name  year  selling_price  km_driven    fuel seller_type  \
# 0      Maruti  2014         450000     145500  Diesel  Individual
# 1       Skoda  2014         370000     120000  Diesel  Individual
# 2       Honda  2006         158000     140000  Petrol  Individual
# 3     Hyundai  2010         225000     127000  Diesel  Individual
# 4      Maruti  2007         130000     120000  Petrol  Individual
# ...       ...   ...            ...        ...     ...         ...
# 8121   Maruti  2013         260000      50000  Petrol  Individual
# 8122  Hyundai  2014         475000      80000  Diesel  Individual
# 8123  Hyundai  2013         320000     110000  Petrol  Individual
# 8124  Hyundai  2007         135000     119000  Diesel  Individual
# 8125   Maruti  2009         382000     120000  Diesel  Individual
#
#      transmission                 owner     mileage   engine   max_power  \
# 0          Manual           First Owner   23.4 kmpl  1248 CC      74 bhp
# 1          Manual          Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2          Manual           Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3          Manual           First Owner   23.0 kmpl  1396 CC      90 bhp
# 4          Manual           First Owner   16.1 kmpl  1298 CC    88.2 bhp
# ...           ...                   ...         ...      ...         ...
# 8121       Manual          Second Owner   18.9 kmpl   998 CC    67.1 bhp
# 8122       Manual          Second Owner  22.54 kmpl  1396 CC   88.73 bhp
# 8123       Manual           First Owner   18.5 kmpl  1197 CC   82.85 bhp
# 8124       Manual  Fourth & Above Owner   16.8 kmpl  1493 CC     110 bhp
# 8125       Manual           First Owner   19.3 kmpl  1248 CC    73.9 bhp
#
#       seats
# 0       5.0
# 1       5.0
# 2       5.0
# 3       5.0
# 4       5.0
# ...     ...
# 8121    5.0
# 8122    5.0
# 8123    5.0
# 8124    5.0
# 8125    5.0
#
# [6718 rows x 12 columns]

# %%
cars_data['mileage'] = cars_data['mileage'].apply(get_brand_name)  #for mileage column only keeping numerical values

# %%
cars_data['engine'] = cars_data['engine'].apply(get_brand_name) #for engine

# %%
cars_data['max_power'] = cars_data['max_power'].apply(get_brand_name) #for max power column

# %%
cars_data['max_power'].unique()
# Out:
# array(['74', '103.52', '78', '90', '88.2', '81.86', '57.5', '37', '67.1',
#        '68.1', '108.45', '60', '73.9', '67', '82', '88.5', '46.3',
#        '88.73', '64.1', '98.6', '88.8', '83.81', '83.1', '47.3', '73.8',
#        '34.2', '35', '81.83', '40.3', '121.3', '138.03', '160.77',
#        '117.3', '116.3', '83.14', '67.05', '168.5', '100', '120.7',
#        '98.63', '175.56', '103.25', '171.5', '100.6', '174.33', '187.74',
#        '170', '78.9', '88.76', '86.8', '108.495', '108.62', '93.7',
#        '103.6', '98.59', '189', '67.04', '68.05', '58.2', '82.85',
#        '81.80', '73', '120', '94.68', '160', '65', '155', '69.01',
#        '126.32', '138.1', '83.8', '126.2', '98.96', '62.1', '86.7', '188',
#        '214.56', '177', '280', '148.31', '254.79', '190', '177.46', '204',
#        '141', '117.6', '241.4', '282', '150', '147.5', '108.5', '103.5',
#        '183', '181.04', '157.7', '164.7', '91.1', '400', '68', '75',
#        '85.8', '87.2', '53', '118', '103.2', '83', '84', '58.16',
#        '147.94', '74.02', '53.3', '80', '88.7', '97.7', '121.36', '162',
#        '140', '94', '100.57', '82.9', '83.11', '70', '153.86', '121',
#        '126.3', '73.97', '171', '69', '99.6', '102', '105', '63', '79.4',
#        '97.9', '63.1', '66.1', '110', '174.5', '53.26', '73.75', '67.06',
#        '64.08', '37.5', '189.3', '158.8', '61.7', '55.2', '71.01',
#        '73.74', '147.9', '71', '77', '121.4', '113.4', '47', '130',
#        '57.6', '138', '52.8', '53.64', '53.5', '76.8', '82.4', '113.42',
#        '76', '84.8', '56.3', '218', '112', '92', '105.5', '169', '95',
#        '72.4', '115', '152', '91.2', '156', '74.9', '62', '105.3',
#        '73.94', '85.80', '85', '118.3', '72', '147.51', '58', '64',
#        '126.24', '76.9', '194.3', '99.23', '89.84', '123.7', '118.35',
#        '99', '241', '136', '261.4', '104.68', '37.48', '104', '88.50',
#        '63.12', '91.7', '102.5', '177.6', '45', '123.37', '147.8', '184',
#        '84.48', '68.07', '74.96', '167.6', '152.87', '112.2', '83.83',
#        '197', '110.4', '104.55', '103', '103.3', '66', '108.6', '165',
#        '163.7', '116.9', '94.93', '127', '198.5', '179.5', '120.69',
#        '121.31', '138.08', '187.7', '80.8', '86.79', '93.87', '116.6',
#        '143', '92.7', '88', '58.33', '78.8', '64.4', '125', '139.01',
#        '254.8', '181', '258', '55.23', '270.9', '265', '157.75', '101',
#        '186', '187.4', '224', '64.9', '148', '35.5', '89.75', '32.8',
#        '91.72', '106', '98.97', '66.6', '86', '65.3', '98.82', '198.25',
#        '38', '142', '132', '174.57', '178', '163.2', '203.2', '177.5',
#        '175', '57', '80.84', '68.4', '167.67', '170.63', '52', '149.5',
#        '48.21', 'bhp', '201.1', '100.5', '144', '194.4', '168.7', '104.5',
#        '103.26', '116.4', '98.79', '80.9', '58.3', '272', '235', '167.62',
#        '170.30', '139.46', '158', '110.5', '82.5', '141.1', '38.4',
#        '197.2', '161', '194', '122.4', '134.10', '60.2', '134', '203',
#        '135.1'], dtype=object)

# %%
cars_data['max_power'].value_counts()['bhp']   #how many time bhp occured in the dataset
# Out:
# 1

# %%
cars_data = cars_data[cars_data['max_power'] != 'bhp']   #removing that row which has 'bhp'

# %%
cars_data
# Out:
#          name  year  selling_price  km_driven    fuel seller_type  \
# 0      Maruti  2014         450000     145500  Diesel  Individual
# 1       Skoda  2014         370000     120000  Diesel  Individual
# 2       Honda  2006         158000     140000  Petrol  Individual
# 3     Hyundai  2010         225000     127000  Diesel  Individual
# 4      Maruti  2007         130000     120000  Petrol  Individual
# ...       ...   ...            ...        ...     ...         ...
# 8121   Maruti  2013         260000      50000  Petrol  Individual
# 8122  Hyundai  2014         475000      80000  Diesel  Individual
# 8123  Hyundai  2013         320000     110000  Petrol  Individual
# 8124  Hyundai  2007         135000     119000  Diesel  Individual
# 8125   Maruti  2009         382000     120000  Diesel  Individual
#
#      transmission                 owner mileage engine max_power  seats
# 0          Manual           First Owner    23.4   1248        74    5.0
# 1          Manual          Second Owner   21.14   1498    103.52    5.0
# 2          Manual           Third Owner    17.7   1497        78    5.0
# 3          Manual           First Owner    23.0   1396        90    5.0
# 4          Manual           First Owner    16.1   1298      88.2    5.0
# ...           ...                   ...     ...    ...       ...    ...
# 8121       Manual          Second Owner    18.9    998      67.1    5.0
# 8122       Manual          Second Owner   22.54   1396     88.73    5.0
# 8123       Manual           First Owner    18.5   1197     82.85    5.0
# 8124       Manual  Fourth & Above Owner    16.8   1493       110    5.0
# 8125       Manual           First Owner    19.3   1248      73.9    5.0
#
# [6717 rows x 12 columns]

# %%
# some of the columns are still in object form we have to convert then into interger or float
cars_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6717 entries, 0 to 8125
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           6717 non-null   object
#  1   year           6717 non-null   int64
#  2   selling_price  6717 non-null   int64
#  3   km_driven      6717 non-null   int64
#  4   fuel           6717 non-null   object
#  5   seller_type    6717 non-null   object
#  6   transmission   6717 non-null   object
#  7   owner          6717 non-null   object
#  8   mileage        6717 non-null   object
#  9   engine         6717 non-null   object
#  10  max_power      6717 non-null   object
#  11  seats          6717 non-null   float64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 682.2+ KB

# %%
cars_data['mileage'] = cars_data['mileage'].astype('float')   #converting mileage into float

# %%
cars_data['engine'] = cars_data['engine'].astype('int')       #converting engine into integer

# %%
cars_data['max_power'] = cars_data['max_power'].astype('float')   #converting max power into float

# %%
cars_data['seats'] = cars_data['seats'].astype(int)        #converting seats intto integer

# %%
cars_data.reset_index()
# Out:
#       index     name  year  selling_price  km_driven    fuel seller_type  \
# 0         0   Maruti  2014         450000     145500  Diesel  Individual
# 1         1    Skoda  2014         370000     120000  Diesel  Individual
# 2         2    Honda  2006         158000     140000  Petrol  Individual
# 3         3  Hyundai  2010         225000     127000  Diesel  Individual
# 4         4   Maruti  2007         130000     120000  Petrol  Individual
# ...     ...      ...   ...            ...        ...     ...         ...
# 6712   8121   Maruti  2013         260000      50000  Petrol  Individual
# 6713   8122  Hyundai  2014         475000      80000  Diesel  Individual
# 6714   8123  Hyundai  2013         320000     110000  Petrol  Individual
# 6715   8124  Hyundai  2007         135000     119000  Diesel  Individual
# 6716   8125   Maruti  2009         382000     120000  Diesel  Individual
#
#      transmission                 owner  mileage  engine  max_power  seats
# 0          Manual           First Owner    23.40    1248      74.00      5
# 1          Manual          Second Owner    21.14    1498     103.52      5
# 2          Manual           Third Owner    17.70    1497      78.00      5
# 3          Manual           First Owner    23.00    1396      90.00      5
# 4          Manual           First Owner    16.10    1298      88.20      5
# ...           ...                   ...      ...     ...        ...    ...
# 6712       Manual          Second Owner    18.90     998      67.10      5
# 6713       Manual          Second Owner    22.54    1396      88.73      5
# 6714       Manual           First Owner    18.50    1197      82.85      5
# 6715       Manual  Fourth & Above Owner    16.80    1493     110.00      5
# 6716       Manual           First Owner    19.30    1248      73.90      5
#
# [6717 rows x 13 columns]

# %%
cars_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6717 entries, 0 to 8125
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           6717 non-null   object
#  1   year           6717 non-null   int64
#  2   selling_price  6717 non-null   int64
#  3   km_driven      6717 non-null   int64
#  4   fuel           6717 non-null   object
#  5   seller_type    6717 non-null   object
#  6   transmission   6717 non-null   object
#  7   owner          6717 non-null   object
#  8   mileage        6717 non-null   float64
#  9   engine         6717 non-null   int32
#  10  max_power      6717 non-null   float64
#  11  seats          6717 non-null   int32
# dtypes: float64(2), int32(2), int64(3), object(5)
# memory usage: 629.7+ KB

# %%
cars_data.describe()
# Out:
#               year  selling_price     km_driven      mileage       engine  \
# count  6717.000000   6.717000e+03  6.717000e+03  6717.000000  6717.000000
# mean   2013.611136   5.263860e+05  7.339834e+04    19.466585  1430.985857
# std       3.897402   5.235504e+05  5.870328e+04     4.048102   493.469198
# min    1994.000000   2.999900e+04  1.000000e+00     0.000000   624.000000
# 25%    2011.000000   2.500000e+05  3.800000e+04    16.800000  1197.000000
# 50%    2014.000000   4.200000e+05  6.820300e+04    19.440000  1248.000000
# 75%    2017.000000   6.500000e+05  1.000000e+05    22.500000  1498.000000
# max    2020.000000   1.000000e+07  2.360457e+06    42.000000  3604.000000
#
#          max_power        seats
# count  6717.000000  6717.000000
# mean     87.766100     5.434271
# std      31.724555     0.983805
# min      32.800000     2.000000
# 25%      67.100000     5.000000
# 50%      81.830000     5.000000
# 75%     100.000000     5.000000
# max     400.000000    14.000000

# %% [markdown]
# Here we can see that the 75% of our cars price is under 6.5 lakh and maximum value in the last quartile is showing max price as  1 cr , that may be a outlier which we have to check.
# Now lets check how many cars are there which have more than 50 lakhs of price.

# %%
#car price which are more than 50 lakhs

cars_data[cars_data['selling_price']>5e6]
# Out:
#                name  year  selling_price  km_driven    fuel seller_type  \
# 132           Lexus  2019        5150000      20000  Petrol      Dealer
# 136   Mercedes-Benz  2017        6000000      37000  Diesel      Dealer
# 139             BMW  2019        5800000       7500  Diesel      Dealer
# 148   Mercedes-Benz  2017        5850000      47000  Diesel      Dealer
# 170           Volvo  2017       10000000      30000  Petrol  Individual
# 384             BMW  2019        5400000       7500  Diesel      Dealer
# 385             BMW  2019        5500000       8500  Diesel      Dealer
# 1071            BMW  2018        6000000      28156  Diesel      Dealer
# 2938            BMW  2020        7200000       5000  Diesel  Individual
# 4671            BMW  2019        5200000      10000  Diesel      Dealer
# 4753            BMW  2018        5500000      22000  Diesel  Individual
# 4766            BMW  2018        6000000      27000  Diesel      Dealer
# 4950           Audi  2019        6223000       7800  Petrol      Dealer
# 4951           Audi  2019        5923000      11500  Petrol      Dealer
# 4952           Audi  2019        6523000      23600  Petrol      Dealer
# 5256  Mercedes-Benz  2019        5200000      17000  Petrol      Dealer
# 6258            BMW  2018        5830000      30000  Diesel  Individual
# 7343            BMW  2019        5800000      21000  Diesel      Dealer
# 7516          Volvo  2018        5500000      50000  Diesel  Individual
# 7930          Volvo  2019        5500000      17000  Diesel  Individual
#
#      transmission           owner  mileage  engine  max_power  seats
# 132     Automatic     First Owner    22.37    2487     214.56      5
# 136     Automatic     First Owner    13.50    2987     254.79      5
# 139     Automatic     First Owner    16.78    1995     190.00      5
# 148     Automatic     First Owner    13.50    2987     282.00      5
# 170     Automatic     First Owner    42.00    1969     400.00      4
# 384     Automatic     First Owner    16.78    1995     190.00      5
# 385     Automatic     First Owner    16.78    1995     190.00      5
# 1071    Automatic     First Owner    17.09    2993     261.40      4
# 2938    Automatic     First Owner    13.38    2993     265.00      7
# 4671    Automatic     First Owner    18.12    1995     190.00      5
# 4753    Automatic     First Owner    17.09    2993     261.40      4
# 4766    Automatic     First Owner    17.09    2993     261.40      4
# 4950    Automatic  Test Drive Car    15.26    1798     187.74      5
# 4951    Automatic  Test Drive Car    15.26    1798     187.74      5
# 4952    Automatic  Test Drive Car    15.26    1798     187.74      5
# 5256    Automatic     First Owner    15.00    1991     194.40      5
# 6258    Automatic     First Owner    17.09    2993     261.40      4
# 7343    Automatic     First Owner    16.78    1995     190.00      5
# 7516    Automatic     First Owner    11.20    1969     235.00      5
# 7930    Automatic     First Owner    18.00    1969     190.00      5

# %% [markdown]
# Looks fine because they are luxury brands only.

# %%
# now for mileage column which have more than 30.00 kmpl or more mileage

# %%
cars_data[cars_data['mileage']>30.00]
# Out:
#         name  year  selling_price  km_driven    fuel seller_type transmission  \
# 35    Maruti  2019         330000      10000     CNG  Individual       Manual
# 170    Volvo  2017       10000000      30000  Petrol  Individual    Automatic
# 866   Maruti  2012         165000      60000     CNG  Individual       Manual
# 2312  Maruti  2013         270000      80000     CNG  Individual       Manual
# 3908  Maruti  2017         260000      67000     CNG  Individual       Manual
# 4004  Maruti  2013         178000      70000     CNG  Individual       Manual
# 5789  Maruti  2019         430000      20000     CNG  Individual       Manual
# 5815  Maruti  2020         370000      16000     CNG  Individual       Manual
#
#              owner  mileage  engine  max_power  seats
# 35    Second Owner    33.44     796      40.30      4
# 170    First Owner    42.00    1969     400.00      4
# 866   Second Owner    30.46     796      47.30      5
# 2312  Second Owner    32.52     998      58.33      5
# 3908   First Owner    33.44     796      40.30      4
# 4004  Second Owner    30.46     796      47.30      5
# 5789   First Owner    32.26     998      58.30      4
# 5815   First Owner    33.00     796      47.30      5

# %% [markdown]
# from the domain knowledge we can say that row 170 which is a Volvo car which is showing mileage of 42kmpl for automaticating transmission and with petrol fuel, which seems not right this is an outlier which i i'm going to drop.

# %%
cars_data = cars_data[cars_data['mileage']!= 42.00]   #removing that Volvo car

# %%
cars_data[cars_data['mileage']>30.00]
# Out:
#         name  year  selling_price  km_driven fuel seller_type transmission  \
# 35    Maruti  2019         330000      10000  CNG  Individual       Manual
# 866   Maruti  2012         165000      60000  CNG  Individual       Manual
# 2312  Maruti  2013         270000      80000  CNG  Individual       Manual
# 3908  Maruti  2017         260000      67000  CNG  Individual       Manual
# 4004  Maruti  2013         178000      70000  CNG  Individual       Manual
# 5789  Maruti  2019         430000      20000  CNG  Individual       Manual
# 5815  Maruti  2020         370000      16000  CNG  Individual       Manual
#
#              owner  mileage  engine  max_power  seats
# 35    Second Owner    33.44     796      40.30      4
# 866   Second Owner    30.46     796      47.30      5
# 2312  Second Owner    32.52     998      58.33      5
# 3908   First Owner    33.44     796      40.30      4
# 4004  Second Owner    30.46     796      47.30      5
# 5789   First Owner    32.26     998      58.30      4
# 5815   First Owner    33.00     796      47.30      5

# %% [markdown]
# That specific Volve car is removed

# %%
cars_data.reset_index()
# Out:
#       index     name  year  selling_price  km_driven    fuel seller_type  \
# 0         0   Maruti  2014         450000     145500  Diesel  Individual
# 1         1    Skoda  2014         370000     120000  Diesel  Individual
# 2         2    Honda  2006         158000     140000  Petrol  Individual
# 3         3  Hyundai  2010         225000     127000  Diesel  Individual
# 4         4   Maruti  2007         130000     120000  Petrol  Individual
# ...     ...      ...   ...            ...        ...     ...         ...
# 6711   8121   Maruti  2013         260000      50000  Petrol  Individual
# 6712   8122  Hyundai  2014         475000      80000  Diesel  Individual
# 6713   8123  Hyundai  2013         320000     110000  Petrol  Individual
# 6714   8124  Hyundai  2007         135000     119000  Diesel  Individual
# 6715   8125   Maruti  2009         382000     120000  Diesel  Individual
#
#      transmission                 owner  mileage  engine  max_power  seats
# 0          Manual           First Owner    23.40    1248      74.00      5
# 1          Manual          Second Owner    21.14    1498     103.52      5
# 2          Manual           Third Owner    17.70    1497      78.00      5
# 3          Manual           First Owner    23.00    1396      90.00      5
# 4          Manual           First Owner    16.10    1298      88.20      5
# ...           ...                   ...      ...     ...        ...    ...
# 6711       Manual          Second Owner    18.90     998      67.10      5
# 6712       Manual          Second Owner    22.54    1396      88.73      5
# 6713       Manual           First Owner    18.50    1197      82.85      5
# 6714       Manual  Fourth & Above Owner    16.80    1493     110.00      5
# 6715       Manual           First Owner    19.30    1248      73.90      5
#
# [6716 rows x 13 columns]

# %%
cars_data_cleaned = cars_data.copy()
cars_data_cleaned
# Out:
#          name  year  selling_price  km_driven    fuel seller_type  \
# 0      Maruti  2014         450000     145500  Diesel  Individual
# 1       Skoda  2014         370000     120000  Diesel  Individual
# 2       Honda  2006         158000     140000  Petrol  Individual
# 3     Hyundai  2010         225000     127000  Diesel  Individual
# 4      Maruti  2007         130000     120000  Petrol  Individual
# ...       ...   ...            ...        ...     ...         ...
# 8121   Maruti  2013         260000      50000  Petrol  Individual
# 8122  Hyundai  2014         475000      80000  Diesel  Individual
# 8123  Hyundai  2013         320000     110000  Petrol  Individual
# 8124  Hyundai  2007         135000     119000  Diesel  Individual
# 8125   Maruti  2009         382000     120000  Diesel  Individual
#
#      transmission                 owner  mileage  engine  max_power  seats
# 0          Manual           First Owner    23.40    1248      74.00      5
# 1          Manual          Second Owner    21.14    1498     103.52      5
# 2          Manual           Third Owner    17.70    1497      78.00      5
# 3          Manual           First Owner    23.00    1396      90.00      5
# 4          Manual           First Owner    16.10    1298      88.20      5
# ...           ...                   ...      ...     ...        ...    ...
# 8121       Manual          Second Owner    18.90     998      67.10      5
# 8122       Manual          Second Owner    22.54    1396      88.73      5
# 8123       Manual           First Owner    18.50    1197      82.85      5
# 8124       Manual  Fourth & Above Owner    16.80    1493     110.00      5
# 8125       Manual           First Owner    19.30    1248      73.90      5
#
# [6716 rows x 12 columns]

# %% [markdown]
# ### Data is cleaned

# %% [markdown]
# ## Now step 2 - Data Vizualization

# %%
cols = ['year','fuel','seller_type','transmission','owner','seats']
for c in cols:
    plt.figure(figsize=(10,6))
    plt.bar(x=f'{c}',height='selling_price',data=cars_data)
    plt.xlabel(f'{c}')
    plt.ylabel('Selling Price')
    plt.title(f'{c} vs Selling Price')
    plt.legend()
    plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ### Observations -
# - Fig 1
#     - Average selling price in 2017 is highest.
#
# - Fig 2
#     - Average selling price of Diesel cars is higher than Petrol .CNG and LPG cars have very less selling price.
#
# - Fig 3
#     - Average selling price of Individual cars is higher followed by Dealer and Trustmark Dealer
#
# - Fig 4
#     - Automaticatic cars tend to have more selling price than manual cars.
#
# - Fig 5
#     - 'First owner' cars have highest selling price surprisingly follwed by 'Test drive car'. Second,third and fourth and above           owner cars has lower selling price.
#
# - Fig 6
#      - 4 seater car has highest selling price followed by 7 seater and 5 seater cars.Other cars has lower selling selling price.

# %%
plt.figure(figsize=(12, 4))

# Fuel
plt.subplot(1, 3, 1)
sns.countplot(data=cars_data, x='fuel')
plt.title('Fuel')

# Seller_Type
plt.subplot(1, 3, 2)
sns.countplot(data=cars_data, x='seller_type')
plt.title('Seller_Type')

# Transmission
plt.subplot(1, 3, 3)
sns.countplot(data=cars_data, x='transmission')
plt.title('Transmission')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### fig 1
#  - In fuel type diesel cars are more than petrol cars and LPG and CNG are very low in number
#
# #### fig 2
# - individual cars highest in numbers as compared to Dealer and Trustmark Dealer
#
# #### fig 3
# - There are more numbers of manual cars in our dataset then automatic cars

# %%
import matplotlib.pyplot as plt

columns = ['year', 'owner']

fig, axs = plt.subplots(len(columns), 1, figsize=(8, 6*len(columns)))

for i, col in enumerate(columns):     #for ploting each column
    # Counting occurrences of each category
    col_counts = cars_data[col].value_counts().sort_index()

    bars = axs[i].bar(col_counts.index, col_counts.values)
    axs[i].set_xlabel(col)
    axs[i].set_ylabel('Count')
    axs[i].set_title(f'Count of Cars by {col}')
    axs[i].grid(True)

# this lines are for count values
    for bar in bars:
        height = bar.get_height()
        axs[i].annotate(f'{height}',
                        xy=(bar.get_x() + bar.get_width() / 2, height),
                        xytext=(0, 3),  # 3 points vertical offset
                        textcoords="offset points",
                        ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %% [markdown]
# From fig 1 we can say we have highest number of 2017 model cars in our dataset.
#
# More than 60% of the cars in our dataset is First Owner cars then followed by 2nd, 3rd, and 4th owner cars.
# There are only 5 cars are there in our dataset of Test Drive Car

# %%
brand_counts = cars_data['name'].value_counts()

plt.figure(figsize=(12, 6))
brand_counts.plot(kind='bar')
plt.xlabel('Brand')
plt.ylabel('Count')
plt.title('Count of Cars by Brand')
plt.xticks(rotation=45)      #rotation of x-axis names for better readability 
plt.show()

# %% [markdown]
# ### Observations -
#
#  - Maruti has highest number of cars followed by Hyundai and Mahindra.

# %% [markdown]
# ### Feature Engineering

# %%
cars_data.columns

# %% [markdown]
# Creating a heatmap

# %%
numerical_features = ['year', 'selling_price', 'km_driven', 'mileage', 'engine', 'max_power', 'seats']

correlation_matrix = cars_data[numerical_features].corr()

# Create heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap of Numerical Features')
plt.show()

# %% [markdown]
#  correlation values above 0.7 or below -0.7 are often considered indicative of high correlation.

# %% [markdown]
# All features have less than 0.7 or above -0.7 . So, we can say that there is high corelation present among the features.

# %% [markdown]
# <!-- while checking multicolinearity between independent columns we can see that significant correlation lies between --
#
# - 'engine' and 'mileage'
# - 'engine' and 'max_power'
# - 'engine' and 'seats' -->

# %% [markdown]
# ### So, Encoding should be done considering above results also

# %% [markdown]
# ### Automatic EDA using pandas profiling

# %%
from ydata_profiling import ProfileReport

# %%
report = ProfileReport(cars_data)

# %%
report.to_file(output_file = 'output.html')

# %% [markdown]
# Applied pandas profiling to see about my cleaned dataset.
# Satisfactory results given.

# %% [markdown]
# ## step 3 - Data Transformation
# - Encoding
# - Scalling

# %% [markdown]
# Rather then directly transforming the data original cleaned data i will create a copy of it.

# %%
encode_data = cars_data.copy()

# %%
encode_data

# %%
#Applying ordinal encoding on Transmission,fuel,seller_type and owner_type column

# %%
cars_data['year'].unique()

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder

# %%
oe_year = OrdinalEncoder(categories = [[1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020]])
year_encoded = oe_year.fit_transform(encode_data[['year']])
encode_data['year'] = year_encoded

# %%
oe_trans = OrdinalEncoder(categories=[['Manual','Automatic']])
oe_fuel= OrdinalEncoder(categories=[['LPG','CNG','Diesel','Petrol']])
oe_seller_type = OrdinalEncoder(categories = [['Dealer','Trustmark Dealer','Individual']])
oe_owner_type = OrdinalEncoder(categories =[['First Owner', 'Second Owner', 'Third Owner',
       'Fourth & Above Owner', 'Test Drive Car']])

# %%
trans_encoded = oe_trans.fit_transform(encode_data[['transmission']]).astype('str')
fuel_encoded = oe_fuel.fit_transform(encode_data[['fuel']])
seller_type_encoded = oe_seller_type.fit_transform(encode_data[['seller_type']])
owner_type_encoded = oe_owner_type.fit_transform(encode_data[['owner']])

# %%
encode_data['transmission'] = trans_encoded
encode_data['fuel'] = fuel_encoded
encode_data['seller_type'] = seller_type_encoded
encode_data['owner'] = owner_type_encoded

# %%
encode_data

# %% [markdown]
# encoding is done.Now name column has categorical values and they are not in ordinal format so we'll use one hot encoding for that.

# %% [markdown]
# Before encoding the name column first we'll separate the dependent column 'selling_price' from our encode_data

# %%
encode_data_ind = encode_data.drop(columns = 'selling_price')

# %%
encode_data_ind = pd.get_dummies(columns = ['name'],data = encode_data_ind, sparse=False)

# %%
encode_data_ind

# %%
cars_data.info()

# %% [markdown]
# ### Encoding is done. Now it's time for scaling.

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaled_dataset = scaler.fit_transform(encode_data_ind)

# %%
scaled_dataset

# %% [markdown]
# ### Scalling is also done. Now our dataset is ready for applying models.

# %%
from sklearn.model_selection import train_test_split

# %%
x = scaled_dataset
y = cars_data['selling_price']

# %%
cars_data.info()

# %%
x.shape

# %%
y.shape

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size =0.2,random_state = 42)

# %% [markdown]
# ### Applying Linear regression model

# %%
model = LinearRegression()

# %%
#Training model

# %%
model.fit(x_train,y_train)

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
y_train_pred = model.predict(x_train)
y_test_pred = model.predict(x_test)

# %% [markdown]
# ### Training r2_score

# %%
training_r2_score = r2_score(y_train,y_train_pred)
print(f"The Training r2 score is :{training_r2_score}")

# %% [markdown]
# ### Testing r2_score

# %%
Testing_r2_score = r2_score(y_test,y_test_pred)
print(f"The Testing r2 score is :{Testing_r2_score}")

# %% [markdown]
# #### Linear Regression model is giving only 76.5 % accuracy on Testing data,whuch is sufficient. We'll try with random_states
#
# #### Let's try with 1000 random_states

# %%
scores = []
for i in range(1000):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = i)
    model = LinearRegression()
    model.fit(x_train,y_train)
    y_test_pred = model.predict(x_test)
    testing_r2_score = r2_score(y_test,y_test_pred)
    scores.append(testing_r2_score)

# %%
np.argmax(scores)

# %%
scores[np.argmax(scores)]

# %% [markdown]
# #### At random_state = 81.82 our Linear regression model is giving highest r2_score of 81.82% . Which is still not suffucient.

# %% [markdown]
# ### So, let's try different models using pipeline

# %% [markdown]
# #### Now we'll use the cleaned 'cars_data' and we'll do econding inside the pipeline. This process is better because it will encode Train and Test data separately which can stop data leakage and gives generalized performance. Using pipelines helps in deployment easily.

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor

from sklearn.metrics import r2_score, mean_squared_error

# %% [markdown]
# ### Now we'll create models through pipelines which is good practice than what i have above

# %%
from sklearn.compose import ColumnTransformer
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error

# %%
X = cars_data.drop('selling_price', axis=1)  # features
y = cars_data['selling_price']  # target variable

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
onehot_encoder = OneHotEncoder(handle_unknown='ignore')
ordinal_encoder = OrdinalEncoder()

# %%
cars_data['year'].dtypes

# %%
cars_data['owner'].unique()

# %%
# Adjust the ColumnTransformer for ordinal encoding with the new ordinal encoder for fuel
encoding_transformer = ColumnTransformer(
    transformers=[
        ('onehot', onehot_encoder, ['name']),
        ('ordinal', ordinal_encoder, ['year','transmission','seller_type','owner','fuel'])
    ],
    remainder='passthrough'  # keep remaining columns as is
)

# %% [markdown]
# ### Here we are not doing becuase we are using Random Forest, Gradient Boosting and XGBoost models is our ensemble model

# %%
# defining  the ensemble model
rf_model = RandomForestRegressor(n_estimators=50, bootstrap=True, random_state = 42)
xgb_model = xgb.XGBRegressor(n_estimators=50, learning_rate =0.1, random_state = 42)
gb_model = GradientBoostingRegressor(n_estimators=50, learning_rate =0.1, random_state = 42)

# %%
from sklearn import set_config   #for pipeline diagram
set_config(display="diagram")

# %% [markdown]
# ### Random Forest

# %%
pipeline_rf = Pipeline([
    ('encoding_transformer', encoding_transformer),
    ('rf_model', rf_model)
])

# %%
pipeline_rf.fit(X_train,y_train)

# %%
y_rf_pred = pipeline_rf.predict(X_test)

# %%
# calculate R^2 score
r2_rf = r2_score(y_test, y_rf_pred)
print(f'R^2 Score: {r2_rf:.3f}')

# %% [markdown]
# ### Gradient Boosting

# %%
pipeline_gb = Pipeline([
    ('encoding_transformer', encoding_transformer),
    ('gb_model', gb_model)
])

# %%
pipeline_gb.fit(X_train , y_train)

# %%
y_gb_pred = pipeline_gb.predict(X_test)

# %%
# R^2 score
r2_gb = r2_score(y_test, y_gb_pred)
print(f'R^2 Score: {r2_gb:.3f}')

# %% [markdown]
# ### XGBoost

# %%
pipeline_xgb = Pipeline([
    ('encoding_transformer', encoding_transformer),
    ('xgb_model', xgb_model)
])

# %%
pipeline_xgb.fit(X_train , y_train)

# %%
y_pred_xgb = pipeline_xgb.predict(X_test)

# %%
r2_xgb = r2_score(y_test , y_pred_xgb)
print(f"R2 score is : {r2_xgb:.3f}")

# %% [markdown]
# XGBoost giving highest accuracy between the models.

# %% [markdown]
# ### Now we apply Ensemble model through Pipeline

# %% [markdown]
# #### Stacking model as ensemble model

# %%
from sklearn.ensemble import StackingRegressor
stacking_model = StackingRegressor(
    estimators=[
        ('rf', rf_model),
        ('gb', gb_model),
        ('xgb', xgb_model)
        
    ],
    final_estimator=xgb_model
)

# %%
pipeline = Pipeline([
    ('encoding_transformer', encoding_transformer),
    ('stacking_model', stacking_model)
])

# %%
# fitfing the pipeline to the training data
pipeline.fit(X_train, y_train)

# %%
# predicting on the testing data
y_pred = pipeline.predict(X_test)

# %%
# calculating R^2 score
r2 = r2_score(y_test, y_pred)
print(f'R^2 Score: {r2:.3f}')

# %%
# calculating adjusted R^2 score
n = len(X_test)
p = X_test.shape[1]
adjusted_r2 = 1 - (1 - r2) * ((n - 1) / (n - p - 1))
print(f'Adjusted R^2 Score: {adjusted_r2:.3f}')

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, StackingRegressor
import xgboost as xgb

# Define the parameter grid for each model
rf_param_grid = {
    'n_estimators': [50, 100, 150],
    'max_depth': [None, 10, 20],
    # Add other RandomForestRegressor hyperparameters here
}

gb_param_grid = {
    'n_estimators': [50, 100, 150],
    'max_depth': [3, 5, 7],
    # Add other GradientBoostingRegressor hyperparameters here
}

xgb_param_grid = {
    'n_estimators': [50, 100, 150],
    'max_depth': [3, 5, 7],
    # Add other XGBRegressor hyperparameters here
}

# Define stacking model with default hyperparameters
rf_model = RandomForestRegressor(bootstrap=True, random_state=42)
xgb_model = xgb.XGBRegressor(learning_rate=0.1, random_state=42)
gb_model = GradientBoostingRegressor(learning_rate=0.1, random_state=42)

stacking_model = StackingRegressor(
    estimators=[
        ('rf', rf_model),
        ('gb', gb_model),
        ('xgb', xgb_model)
    ],
    final_estimator=xgb_model
)

# Define the pipeline
pipeline = Pipeline([
    ('encoding_transformer', encoding_transformer),
    ('stacking_model', stacking_model)
])

# Define parameter grid for the pipeline
param_grid = {
    'stacking_model_rf_n_estimators': rf_param_grid['n_estimators'],
    'stacking_model_rf_max_depth': rf_param_grid['max_depth'],
    'stacking_model_gb_n_estimators': gb_param_grid['n_estimators'],
    'stacking_model_gb_max_depth': gb_param_grid['max_depth'],
    'stacking_model_xgb_n_estimators': xgb_param_grid['n_estimators'],
    'stacking_model_xgb_max_depth': xgb_param_grid['max_depth'],
    # Add other hyperparameters for the stacking model here
}

# Perform GridSearchCV
grid_search = GridSearchCV(pipeline, param_grid, cv=5, n_jobs=-1)
grid_search.fit(X_train, y_train)

# Get the best parameters and best score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

print("Best Parameters:", best_params)
print("Best Score:", best_score)

# %% [markdown]
# ### Our Ensemble model is giving highest accuracy.

# %% [markdown]
# ### Model is ready now it's time for prediction.

# %%
X_test.sample(10)    #taking sample from test data for input

# %%
# Creating input_variable with independent column values
input_variable = pd.DataFrame({
    'name': ['Tata'],  # Example value for the 'name' column
    'year': [2014],  # Example value for the 'year' column
    'km_driven': [45000],  # Example value for the 'km_driven' column
    'fuel': ['Diesel'],  # Example value for the 'fuel' column
    'seller_type': ['Individual'],  # Example value for the 'seller_type' column
    'transmission': ['Manual'],  # Example value for the 'transmission' column
    'owner': ['First Owner'],  # Example value for the 'owner' column
    'mileage': [19.09],  # Example value for the 'mileage' column
    'engine': [1405],  # Example value for the 'engine' column
    'max_power': [69.01],  # Example value for the 'max_power' column
    'seats': [5]  # Example value for the 'seats' column
})

# %% [markdown]
# ### Prediction of selling_price by the ensemble model

# %%
predicted_price = pipeline.predict(input_variable)
predicted_price

# %%
import pickle as pk

# %%
pk.dump(pipeline,open('ML_final.pkl','wb'))
